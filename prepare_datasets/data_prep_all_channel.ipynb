# %%
import glob
import os
from PIL import Image
import numpy as np
Image.MAX_IMAGE_PIXELS = None
import sys
import math
import cv2

def mask_mxif(sample_id,marker):
    workdir = '/mnt/1T/baos1/GCA/data/MXIF/cyclegan/'
    
    
    tissue_mask = cv2.imread('%s/%s_TISSUE_MASK.tif' % (workdir,sample_id),cv2.IMREAD_GRAYSCALE)
    tissue_mask[tissue_mask == 0 ] = 0
    tissue_mask[tissue_mask == 255] = 1
    
    img = cv2.imread('%s/%s_%s.tif' % (workdir,sample_id,marker))
    img_masked = cv2.bitwise_and(img,img,mask = tissue_mask)
    cv2.imwrite('%s/%s_%s_masked.tif' % (workdir, sample_id,marker),img_masked)
      
def resize_mxif_to_ihe_space(x_size,y_size,sample_id,marker):
    workdir = '/mnt/1T/baos1/GCA/data/MXIF/cyclegan/'
    workdir_mxif_resize = '/mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/'
    he_dim = 0.5036
    print(sample_id)
#     sample_id = 'GCA002ACB'
#     img = cv2.imread('%s/%s_ALL.tif' % (workdir,sample_id))
    img = cv2.imread('%s/%s_%s_masked.tif' % (workdir,sample_id,marker))
    h,w,dim = img.shape
    dim = (int(w * x_size/he_dim), int(h * y_size / he_dim))

    # resize image
    resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
    cv2.imwrite('%s/%s_%s_masked_IN_IHE.tif' % (workdir_mxif_resize,sample_id,marker),resized)
    
    
def roi_MXIF(sample_id,marker,x,y,w,h):
    print(sample_id)
    target_dir = '/mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi'
#     img = cv2.imread('/mnt/1T/baos1/GCA/data/MXIF/cyclegan/cropped_ihe_one_third/GCA002ACB_IHE_cropped.tiff')
    img = cv2.imread('/mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/%s_%s_masked_IN_IHE.tif' % (sample_id,marker))

    img_to_save = img[y:y+h,x:x+w,:]
    cv2.imwrite('%s/%s_%s_masked_IN_IHE_ROI.tif' % (target_dir,sample_id,marker),img_to_save)

def crop256_MXIF(sample_id,marker,w,h):
    src_dir = '/mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi'
    target_dir = '%s/crop256' % src_dir
    #print('Number of arguments:%s' % sys.argv[1])
    raw_img_path = '%s/%s_%s_masked_IN_IHE_ROI.tif' % (src_dir,sample_id,marker)
    print(raw_img_path)
    # raw_img_name = sys.argv[2]
    # w = 7956
    # h = 5292
    roundup_w = math.ceil(w/256)#int(sys.argv[3])
    roundup_h = math.ceil(h/256)#int(sys.argv[4])

    img = Image.open(raw_img_path)#.convert('RGB')
    img_cropped_zero_padding = img.crop((0, 0, 256* roundup_w, 256*roundup_h ))

#     save_image_path = '%s/%s_ALL_IN_IHE_ROI_crop256.tif' % (target_dir,sample_id)
    save_image_path = '%s/%s_%s_masked_IN_IHE_ROI_crop256.tif' % (target_dir,sample_id,marker)
    img_cropped_zero_padding.save(save_image_path, 'TIFF')
    
def split_MXIF(sample_id,patch_size, marker_list):    
    src_dir = '/mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/crop256'
    
    
    imgs = []
    for marker in marker_list:
        suffix = '%s_masked_IN_IHE_ROI_crop256' % marker
        raw_img_path = '%s/%s_%s.tif' % (src_dir,sample_id,suffix) 
        img = Image.open(raw_img_path)
        imgs.append(img)
        break
    
    w,h = imgs[0].size
#     img = Image.open(raw_img_path)
    w,h = img.size

    xUpper = math.ceil((w)/patch_size)
    #yUpper = math.ceil((h-500)/patch_size)
    yUpper = math.ceil(h/patch_size) # no need to minus 500...
    # for i in range (0,curX-1):
    #     for j in range (0,yUpper-1):
    for i in range (0,xUpper):
        print('i:%d' % i)
        for j in range (0,yUpper):
            print('j:%d' % j)
            tmp_img_list = []
            
            for marker in marker_list:
                suffix = '%s_masked_IN_IHE_ROI_crop256' % marker
                raw_img_path = '%s/%s_%s.tif' % (src_dir,sample_id,suffix) 
                img = Image.open(raw_img_path)
            
            
            
            
#             for img in imgs:
#                 #start point = (0,0)
                curX = 0 + i * patch_size
                curY = 0 + j * patch_size
                targetX = curX + patch_size
                targetY = curY + patch_size
                img_cropped = img.crop((curX, curY, targetX, targetY))
                tmp_img_list.append(img_cropped)
        
            imgs_comb = np.hstack((np.asarray(train_img) for train_img in tmp_img_list ) )

            raw_img_path = '%s/%s_%s.tif' % (src_dir,sample_id,marker)
            tmp_file_name = '%s/patch/%s/%s_ALL_CHANNEL_%s_%s.png' % (src_dir,sample_id,sample_id,i,j) 
            imgs_comb = Image.fromarray( imgs_comb)
            imgs_comb.save( tmp_file_name, 'PNG')

# %%
marker_list = ['ACTG1','ACTININ','BCATENIN','CD11B','CD20','CD3D','CD45','CD4','CD68','CD8','CGA','COLLAGEN','DAPI','ERBB2','FOXP3','HLAA','LYSOZYME','MUC2','NAKATPASE','OLFM4','PANCK','PCNA','PEGFR','PSTAT3','SMA','SOX9','VIMENTIN']

sample_list = ['GCA002ACB']

def preprocess_ALL(sample_list,marker_list):
    for sample_id in sample_list:
        for marker in  marker_list:
            print(marker)
#             mask_mxif(sample_id,marker)
# #             resize_mxif_to_ihe_space(x_size,y_size,sample_id,marker)
#             resize_mxif_to_ihe_space(0.32430937910244567 ,0.32411575385040403,sample_id,marker)
# #             roi_MXIF(sample_id,marker,x,y,w,h)
#             roi_MXIF(sample_id,marker, 5028,3480,7956,5292)
# #             crop256_MXIF('GCA002ACB', 7956, 5292)
#             crop256_MXIF(sample_id,marker, 7956, 5292)
    
        patch_size = 256
        split_MXIF(sample_id,patch_size, marker_list)

# %%
marker_list = ['ACTG1','ACTININ','BCATENIN','CD11B','CD20','CD3D','CD45','CD4','CD68','CD8','CGA','COLLAGEN','DAPI','ERBB2','FOXP3','HLAA','LYSOZYME','MUC2','NAKATPASE','OLFM4','PANCK','PCNA','PEGFR','PSTAT3','SMA','SOX9','VIMENTIN']

# sample_list=['GCA002ACB']
# preprocess_ALL(sample_list,marker_list)


nested_dict2 = {'GCA002TIB': {'x_size':0.32431821274665457 ,'y_size':0.32412503668916937,'x':256,'y':6352,'w':6160,'h':4368},
              'GCA003ACA': {'x_size': 0.32432108239095314,'y_size':0.32412536691601174,'x':4250,'y':3141,'w':1016,'h':1152},
              'GCA003TIB': {'x_size':0.3243145161290323 ,'y_size':0.32412004992079874,'x':96,'y':640,'w':8320,'h':12144},
              'GCA004TIB': {'x_size':0.3243017666392769 ,'y_size':0.32411196307600687,'x':0,'y':0,'w':10956,'h':8645},
              'GCA011ACB': {'x_size': 0.32430597077244255,'y_size':0.3241287986704653,'x':0,'y':0,'w':15423,'h':10843},
              'GCA011TIB': {'x_size': 0.32430687474077147,'y_size':0.3241229633959231,'x':7584,'y':1812,'w':4224,'h':6072},
              'GCA012ACB': {'x_size': 0.32430941507114,'y_size':0.3241153973509934,'x':9736,'y':1176,'w':4480,'h':6408},
              'GCA012TIB': {'x_size':0.32431067048081824 ,'y_size':0.32411197154821314,'x':1026,'y':1970,'w':3084,'h':2178}}



def preprocess_ALL2(sample_list,marker_list):
    for sample_id in sample_list:
        for marker in  marker_list:
            print(marker)
            mask_mxif(sample_id,marker)
#             resize_mxif_to_ihe_space(x_size,y_size,sample_id,marker)
            resize_mxif_to_ihe_space(nested_dict2[sample_id]['x_size'] ,nested_dict2[sample_id]['y_size'],sample_id,marker)
#             roi_MXIF(sample_id,marker,x,y,w,h)
            roi_MXIF(sample_id,marker, nested_dict2[sample_id]['x'],nested_dict2[sample_id]['y'],nested_dict2[sample_id]['w'],nested_dict2[sample_id]['h'])
#             crop256_MXIF('GCA002ACB', 7956, 5292)
            crop256_MXIF(sample_id,marker, nested_dict2[sample_id]['w'],nested_dict2[sample_id]['h'])
    
        patch_size = 256
        split_MXIF(sample_id,patch_size, marker_list)
        
*sample_list, = nested_dict2
preprocess_ALL2(sample_list,marker_list)

sample_list=['GCA002ACB']
preprocess_ALL(sample_list,marker_list)
# Out:
# ACTG1
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_ACTG1_masked_IN_IHE_ROI.tif
# ACTININ
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_ACTININ_masked_IN_IHE_ROI.tif
# BCATENIN
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_BCATENIN_masked_IN_IHE_ROI.tif
# CD11B
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_CD11B_masked_IN_IHE_ROI.tif
# CD20
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_CD20_masked_IN_IHE_ROI.tif
# CD3D
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_CD3D_masked_IN_IHE_ROI.tif
# CD45
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_CD45_masked_IN_IHE_ROI.tif
# CD4
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_CD4_masked_IN_IHE_ROI.tif
# CD68
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_CD68_masked_IN_IHE_ROI.tif
# CD8
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_CD8_masked_IN_IHE_ROI.tif
# CGA
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_CGA_masked_IN_IHE_ROI.tif
# COLLAGEN
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_COLLAGEN_masked_IN_IHE_ROI.tif
# DAPI
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_DAPI_masked_IN_IHE_ROI.tif
# ERBB2
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_ERBB2_masked_IN_IHE_ROI.tif
# FOXP3
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_FOXP3_masked_IN_IHE_ROI.tif
# HLAA
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_HLAA_masked_IN_IHE_ROI.tif
# LYSOZYME
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_LYSOZYME_masked_IN_IHE_ROI.tif
# MUC2
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_MUC2_masked_IN_IHE_ROI.tif
# NAKATPASE
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_NAKATPASE_masked_IN_IHE_ROI.tif
# OLFM4
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_OLFM4_masked_IN_IHE_ROI.tif
# PANCK
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_PANCK_masked_IN_IHE_ROI.tif
# PCNA
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_PCNA_masked_IN_IHE_ROI.tif
# PEGFR
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_PEGFR_masked_IN_IHE_ROI.tif
# PSTAT3
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_PSTAT3_masked_IN_IHE_ROI.tif
# SMA
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_SMA_masked_IN_IHE_ROI.tif
# SOX9
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_SOX9_masked_IN_IHE_ROI.tif
# VIMENTIN
# GCA002TIB
# GCA002TIB
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA002TIB_VIMENTIN_masked_IN_IHE_ROI.tif
# i:0
# j:0
# <ipython-input-21-bbe2c8f7c6ce>:101: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   imgs_comb = np.hstack((np.asarray(train_img) for train_img in tmp_img_list ) )
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:1
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:2
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:3
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:4
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:5
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:6
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:7
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:8
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:9
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:10
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:11
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:12
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:13
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:14
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:15
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:16
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:17
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:18
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:19
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:20
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:21
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:22
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:23
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# i:24
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# ACTG1
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_ACTG1_masked_IN_IHE_ROI.tif
# ACTININ
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_ACTININ_masked_IN_IHE_ROI.tif
# BCATENIN
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_BCATENIN_masked_IN_IHE_ROI.tif
# CD11B
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_CD11B_masked_IN_IHE_ROI.tif
# CD20
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_CD20_masked_IN_IHE_ROI.tif
# CD3D
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_CD3D_masked_IN_IHE_ROI.tif
# CD45
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_CD45_masked_IN_IHE_ROI.tif
# CD4
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_CD4_masked_IN_IHE_ROI.tif
# CD68
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_CD68_masked_IN_IHE_ROI.tif
# CD8
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_CD8_masked_IN_IHE_ROI.tif
# CGA
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_CGA_masked_IN_IHE_ROI.tif
# COLLAGEN
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_COLLAGEN_masked_IN_IHE_ROI.tif
# DAPI
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_DAPI_masked_IN_IHE_ROI.tif
# ERBB2
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_ERBB2_masked_IN_IHE_ROI.tif
# FOXP3
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_FOXP3_masked_IN_IHE_ROI.tif
# HLAA
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_HLAA_masked_IN_IHE_ROI.tif
# LYSOZYME
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_LYSOZYME_masked_IN_IHE_ROI.tif
# MUC2
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_MUC2_masked_IN_IHE_ROI.tif
# NAKATPASE
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_NAKATPASE_masked_IN_IHE_ROI.tif
# OLFM4
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_OLFM4_masked_IN_IHE_ROI.tif
# PANCK
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_PANCK_masked_IN_IHE_ROI.tif
# PCNA
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_PCNA_masked_IN_IHE_ROI.tif
# PEGFR
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_PEGFR_masked_IN_IHE_ROI.tif
# PSTAT3
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_PSTAT3_masked_IN_IHE_ROI.tif
# SMA
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_SMA_masked_IN_IHE_ROI.tif
# SOX9
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_SOX9_masked_IN_IHE_ROI.tif
# VIMENTIN
# GCA003ACA
# GCA003ACA
# /mnt/1T/baos1/GCA/data/MXIF/cyclegan/mxif_in_ihe_space/roi/GCA003ACA_VIMENTIN_masked_IN_IHE_ROI.tif
# i:0
# j:0
# j:1
# j:2
# j:3
# j:4
# i:1
# j:0
# j:1
# j:2
# j:3
# j:4
# i:2
# j:0
# j:1
# j:2
# j:3
# j:4
# i:3
# j:0
# j:1
# j:2
# j:3
# j:4
# ACTG1

# %%
pwd
# Out:
# '/data/baos1/GCA/dailyCode/pytorch-CycleGAN-and-pix2pix/prepare_datasets'

# %%
nested_dict = { 'GCA002ACB': {'x_size': 0.32430937910244567,'y_size':0.32411575385040403,'x':5028,'y':3480,'w':7956,'h':5292},
                'GCA002TIB': {'x_size':0.32431821274665457 ,'y_size':0.32412503668916937,'x':256,'y':6352,'w':6160,'h':4368},
              'GCA003ACA': {'x_size': 0.32432108239095314,'y_size':0.32412536691601174,'x':4250,'y':3141,'w':1016,'h':1152},
              'GCA003TIB': {'x_size':0.3243145161290323 ,'y_size':0.32412004992079874,'x':96,'y':640,'w':8320,'h':12144},
              'GCA004TIB': {'x_size':0.3243017666392769 ,'y_size':0.32411196307600687,'x':0,'y':0,'w':10956,'h':8645},
              'GCA011ACB': {'x_size': 0.32430597077244255,'y_size':0.3241287986704653,'x':0,'y':0,'w':15423,'h':10843},
              'GCA011TIB': {'x_size': 0.32430687474077147,'y_size':0.3241229633959231,'x':7584,'y':1812,'w':4224,'h':6072},
              'GCA012ACB': {'x_size': 0.32430941507114,'y_size':0.3241153973509934,'x':9736,'y':1176,'w':4480,'h':6408},
              'GCA012TIB': {'x_size':0.32431067048081824 ,'y_size':0.32411197154821314,'x':1026,'y':1970,'w':3084,'h':2178}}

# %%
nested_dict2 = {'GCA002TIB': {'x_size':0.32431821274665457 ,'y_size':0.32412503668916937,'x':256,'y':6352,'w':6160,'h':4368},
              'GCA003ACA': {'x_size': 0.32432108239095314,'y_size':0.32412536691601174,'x':4250,'y':3141,'w':1016,'h':1152},
              'GCA003TIB': {'x_size':0.3243145161290323 ,'y_size':0.32412004992079874,'x':96,'y':640,'w':8320,'h':12144},
              'GCA004TIB': {'x_size':0.3243017666392769 ,'y_size':0.32411196307600687,'x':0,'y':0,'w':10956,'h':8645},
              'GCA011ACB': {'x_size': 0.32430597077244255,'y_size':0.3241287986704653,'x':0,'y':0,'w':15423,'h':10843},
              'GCA011TIB': {'x_size': 0.32430687474077147,'y_size':0.3241229633959231,'x':7584,'y':1812,'w':4224,'h':6072},
              'GCA012ACB': {'x_size': 0.32430941507114,'y_size':0.3241153973509934,'x':9736,'y':1176,'w':4480,'h':6408},
              'GCA012TIB': {'x_size':0.32431067048081824 ,'y_size':0.32411197154821314,'x':1026,'y':1970,'w':3084,'h':2178}}

# %%
*k, = nested_dict2

# %%
k
# Out:
# ['GCA002TIB',
#  'GCA003ACA',
#  'GCA003TIB',
#  'GCA004TIB',
#  'GCA011ACB',
#  'GCA011TIB',
#  'GCA012ACB',
#  'GCA012TIB']

# %%
sample_list=['GCA002ACB']
preprocess_ALL(sample_list,marker_list)
# Out:
# ACTG1
# ACTININ
# BCATENIN
# CD11B
# CD20
# CD3D
# CD45
# CD4
# CD68
# CD8
# CGA
# COLLAGEN
# DAPI
# ERBB2
# FOXP3
# HLAA
# LYSOZYME
# MUC2
# NAKATPASE
# OLFM4
# PANCK
# PCNA
# PEGFR
# PSTAT3
# SMA
# SOX9
# VIMENTIN
# i:0
# j:0
# <ipython-input-2-bbe2c8f7c6ce>:101: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   imgs_comb = np.hstack((np.asarray(train_img) for train_img in tmp_img_list ) )
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:1
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:2
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:3
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:4
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:5
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:6
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:7
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:8
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:9
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:10
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:11
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:12
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:13
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:14
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:15
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:16
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:17
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:18
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:19
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:20
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:21
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:22
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:23
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:24
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:25
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:26
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:27
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:28
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:29
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:30
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
# i:31
# j:0
# j:1
# j:2
# j:3
# j:4
# j:5
# j:6
# j:7
# j:8
# j:9
# j:10
# j:11
# j:12
# j:13
# j:14
# j:15
# j:16
# j:17
# j:18
# j:19
# j:20
